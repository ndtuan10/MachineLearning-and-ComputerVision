# %% [markdown]
# <a href="https://colab.research.google.com/github/ndtuan10/Machine-Learning/blob/main/BaiTap/Some__Machine_Learning_Classification__Algorithms%2BVGG16_fc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os 
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/'
path_train = path + 'training/'
path_test = path + 'evaluation/'
path_validation = path + '/validation/'

# %%
lables_train = os.listdir(path_train)
A_train = []
B_train = []
for i in lables_train:
  lables_path = path_train + i + '/'
  print(i)
  for file in os.listdir(lables_path):
    f = lables_path + file 
    print(f)
    A_train.append(np.load(f))
    B_train.append(i)
  print('Complete loading a class')

print('Complete loading')
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1244.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1245.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1246.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1247.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1248.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1249.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/125.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1250.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1251.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1253.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/training/Meat/1252.npy
# ...

# %%
lables_test = os.listdir(path_test)
A_test = []
B_test = []
for i in lables_test:
  lables_path = path_test + i + '/'
  print(i)
  for file in os.listdir(lables_path):
    f = lables_path + file 
    print(f)
    A_test.append(np.load(f))
    B_test.append(i)
  print('Complete loading a class - Test')

print('Complete loading - Test')
# Out:
# Vegetable-Fruit
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/0.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/1.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/10.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/102.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/103.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/101.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/104.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/100.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/106.npy
# /content/drive/My Drive/CS114_A/Food-11/features/VGG16_fc2/evaluation/Vegetable-Fruit/105.npy
# ...

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %% [markdown]
# **SVC với OvR**

# %%
model = SVC(decision_function_shape = 'ovr')
model.fit(A_train, B_train)
B_pred = model.predict(A_test)
print('Do chinh xac (Accuracy) SVC voi OVR:', metrics.accuracy_score(B_pred, B_test)) 
print('Hinh dang (shape):', model.support_vectors_.shape)
print('Kich thuoc (size): ', model.support_vectors_.size)
# Out:
# Do chinh xac (Accuracy) SVC voi OVR: 0.8565488565488566
# Hinh dang (shape): (6262, 4096)
# Kich thuoc (size):  25649152

# %% [markdown]
# **LinearSVC**

# %%
model = SVC(kernel='linear')
model.fit(A_train,B_train)
B_pred = model.predict(A_test)
print('Do chinh xac (Accuracy) LinearSVC:', metrics.accuracy_score(B_pred, B_test)) 
print('Hinh dang (shape):', model.support_vectors_.shape)
print('Kich thuoc (size): ', model.support_vectors_.size)
# Out:
# Do chinh xac (Accuracy) LinearSVC: 0.8405108405108405
# Hinh dang (shape): (5316, 4096)
# Kich thuoc (size):  21774336

# %% [markdown]
# **SVC với OvO**

# %%
model = SVC(decision_function_shape='ovo')
model.fit(A_train,B_train)
B_pred = model.predict(A_test)
print('Do chinh xac (Accuracy) SVC voi OVO:', metrics.accuracy_score(B_pred, B_test))
print('Hinh dang (shape):', model.support_vectors_.shape)
print('Kich thuoc (size): ', model.support_vectors_.size)
# Out:
# Do chinh xac (Accuracy) SVC voi OVO: 0.8565488565488566
# Hinh dang (shape): (6262, 4096)
# Kich thuoc (size):  25649152

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,11):
  model = KNeighborsClassifier(n_neighbors=i)
  model.fit(A_train,B_train)
  B_pred = model.predict(A_test)
  print('Do chinh xac (Accuracy) KNN: ', metrics.accuracy_score(B_pred,B_test))
# Out:
# Do chinh xac (Accuracy) KNN:  0.7341847341847342
# Do chinh xac (Accuracy) KNN:  0.7193347193347194
# Do chinh xac (Accuracy) KNN:  0.7555687555687556
# Do chinh xac (Accuracy) KNN:  0.7588357588357588
# Do chinh xac (Accuracy) KNN:  0.7686367686367687
# Do chinh xac (Accuracy) KNN:  0.7745767745767745
# Do chinh xac (Accuracy) KNN:  0.7733887733887734
# Do chinh xac (Accuracy) KNN:  0.7787347787347787
# Do chinh xac (Accuracy) KNN:  0.7828927828927829
# Do chinh xac (Accuracy) KNN:  0.7846747846747847

# %%
model = KNeighborsClassifier(n_neighbors = 10)
model.fit(A_train, B_train)
B_pred = model.predict(A_test)
print('Do chinh xac (Accuracy) KNN cuoi cung: ', metrics.accuracy_score(B_pred, B_test))
# Out:
# Do chinh xac (Accuracy) KNN cuoi cung:  0.7846747846747847

# %% [markdown]
# **Bayes**

# %%
from sklearn.naive_bayes import BernoulliNB
model = bnb = BernoulliNB()
model.fit(A_train, B_train)
B_pred = model.predict(A_test)
print('Do chinh xac (Accuracy) Bayes: ' ,metrics.accuracy_score(B_pred, B_test))
print('Hinh dang (shape):', bnb.feature_count_.shape)
print('Kich thuoc (size): ', bnb.feature_count_.size)
# Out:
# Do chinh xac (Accuracy) Bayes:  0.7377487377487377
# Hinh dang (shape): (11, 4096)
# Kich thuoc (size):  45056

# %% [markdown]
# **K-Means**

# %%
import numpy as np
import os
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
kmeans = KMeans(n_clusters = 11).fit(A_train)
kmeans.labels_
kmeans.cluster_centers_
B_pred = kmeans.predict(A_test)

# %%
print('Accuracy rand: ', metrics.adjusted_rand_score(B_test, B_pred))
print('Accuracy mutual: ', metrics.adjusted_mutual_info_score(B_test, B_pred))
print('Accuracy hom: ', metrics.homogeneity_score(B_test, B_pred))
print('Accuracy completeness: ', metrics.completeness_score(B_test, B_pred))
print('Accuracy mallows: ', metrics.fowlkes_mallows_score(B_test, B_pred))
size_kmean = (11, 4096)
print('Kich thuoc (size):', size_kmean)
print('predict ', B_pred)
print('train ', B_train)
print(kmeans.labels_)
print('test', B_test)
# Out:
# Accuracy rand:  0.29249829442561337
# Accuracy mutual:  0.4301404435481745
# Accuracy hom:  0.4330783330238917
# Accuracy completeness:  0.4347028713445638
# Accuracy mallows:  0.3707924053584627
# Kich thuoc (size): (11, 4096)
# predict  [ 5  5 10 ...  7  7  7]
# ...

# %% [markdown]
# **Mobile-Net**

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
Path_dir = '/content/drive/My Drive/CS114_A/Food-11/img/'
path_train = Path_dir + 'training/'
path_test = Path_dir + 'evaluation/'
path_valid = Path_dir + 'validation/'

# %%
classNames = os.listdir(path_test)
print(classNames)
# Out:
# ['Rice', 'Seafood', 'Vegetable-Fruit', 'Noodles-Pasta', 'Egg', 'Soup', 'Fried food', 'Meat', 'Dessert', 'Bread', 'Dairy product']

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
def loadData(path):
  A, B = [], []
  for folder_name in classNames:
    folder_path = os.path.join(Path_dir, path, folder_name)
    i = 0
    for fname in os.listdir(folder_path):
      if (i<700):
        fpath = os.path.join(folder_path, fname)
        print(fpath)
        img = image.load_img(fpath, target_size=(224,224))
        img_data = image.img_to_array(img)
        A.append(img_data)
        B.append(folder_name)
        i = i+1
  # Preprocessing
  A = np.asarray(A)/255.0
  B = np.asarray(B)
  print('Loading completed. ')
  return A,B

# %%
A_train, B_train = loadData(path_train)
A_test, B_test = loadData(path_test)
A_valid, B_valid = loadData(path_valid)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/267.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/269.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/27.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/270.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/273.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/271.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/272.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/275.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/274.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/276.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/277.jpg
# /content/drive/My Drive/CS114_A/Food-11/img/evaluation/Fried food/278.jpg
# ...

# %%
print('A_train: {}, B_train: {}, A_valid: {}, B_valid: {}, A_test: {}, B_test: {}'.format(A_train.shape, B_train.shape, A_valid.shape, B_valid.shape, A_test.shape, B_test.shape))
# Out:
# A_train: (6749, 224, 224, 3), B_train: (6749,), A_valid: (3450, 224, 224, 3), B_valid: (3450,), A_test: (3347, 224, 224, 3), B_test: (3347,)

# %%
result = {
    'Data':["A_train", "B_train", "A_valid", "B_valid", "A_test", "B_test"],
    'Shape': [A_train.shape, B_train.shape, A_valid.shape, B_valid.shape, A_test.shape, B_test.shape]
}
pd.DataFrame(result)
# Out:
#       Data                Shape
# 0  A_train  (6749, 224, 224, 3)
# 1  B_train              (6749,)
# 2  A_valid  (3450, 224, 224, 3)
# 3  B_valid              (3450,)
# 4   A_test  (3347, 224, 224, 3)
# 5   B_test              (3347,)

# %%
# One hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
B_train = lb.fit_transform(B_train)
B_valid = lb.fit_transform(B_valid)

# %%
model = Sequential()

mobileV2 = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),include_top=False, weights='imagenet')
mobileV2.trainable = False

model.add(mobileV2)
model.add(GlobalAveragePooling2D())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dense(len(classNames)))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               655872
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 11)                5643
# _________________________________________________________________
# activation_5 (Activation)    (None, 11)                0
# ...

# %%
aug = ImageDataGenerator(rotation_range=0.18,zoom_range=0.15,width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True)
learning_rate = 0.01
epochs = 20
batch_size = 64
opt = Adam(learning_rate=learning_rate)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print('Start training')
H = model.fit(aug.flow(A_train,B_train,batch_size=batch_size), validation_data=(A_valid,B_valid), steps_per_epoch=A_train.shape[0]//batch_size, epochs=epochs, verbose=1)
# Out:
# Start training
# Epoch 1/20
# 105/105 [==============================] - 390s 4s/step - loss: 0.9695 - accuracy: 0.6987 - val_loss: 1.2810 - val_accuracy: 0.6809
# Epoch 2/20
# 105/105 [==============================] - 390s 4s/step - loss: 0.6505 - accuracy: 0.7903 - val_loss: 0.9829 - val_accuracy: 0.7165
# Epoch 3/20
# 105/105 [==============================] - 389s 4s/step - loss: 0.5617 - accuracy: 0.8141 - val_loss: 0.7379 - val_accuracy: 0.7612
# Epoch 4/20
# 105/105 [==============================] - 391s 4s/step - loss: 0.5086 - accuracy: 0.8299 - val_loss: 0.6586 - val_accuracy: 0.7922
# Epoch 5/20
# 105/105 [==============================] - 393s 4s/step - loss: 0.4813 - accuracy: 0.8347 - val_loss: 0.7766 - val_accuracy: 0.7577
# Epoch 6/20
# 105/105 [==============================] - 388s 4s/step - loss: 0.4571 - accuracy: 0.8438 - val_loss: 0.8631 - val_accuracy: 0.7522
# Epoch 7/20
# ...

# %%
model.save('MobilenetV2.h5')

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import confusion_matrix, classification_report

label_test = lb.fit_transform(B_test)

B_pred = model.predict(A_test)

B_pred = np.argmax(B_pred, axis = 1)
label_test = np.argmax(label_test, axis = 1)

B_pred = B_pred.astype('str')
label_test = label_test.astype('str')

for i in range(B_pred.shape[0]):
  B_pred[i] = classname[int(B_pred[i])]
  label_test[i] = classname[int(label_test[i])]

print('Confusion Matrix')
confusion_matrix(label_test, B_pred)
# Out:
# Confusion Matrix
# array([[ 91,   0,   0,   0,   0,   1,   0,   1,   1,   1,   1],
#        [  0, 262,   0,   0,   9,   4,  12,   1,   1,  11,   3],
#        [  1,   4, 474,   2,   7,   1,   2,   4,   2,   2,   1],
#        [  3,   0,   0, 143,   0,   0,   0,   0,   0,   1,   0],
#        [  1,  13,   3,   0, 393,   2,   0,   2,  12,   2,   4],
#        [  4,  11,   8,   0,  20, 241,  13,   2,  18,   8,  10],
#        [  1,   3,   0,   0,   2,   1, 128,   5,   3,   3,   2],
#        [  5,  38,  25,   1,  57,  32,  45, 250,  18,  14,  15],
#        [  1,   4,   5,   0,  12,   4,   7,   2, 243,   3,   6],
#        [  0,   4,   1,   0,   1,   2,   0,   1,   0, 222,   0],
#        [  3,  13,  16,   0,  25,  27,   4,   5,  57,   2, 216]])

# %%
print('Classification Report')
print(classification_report(label_test, B_pred, target_names=classname))
# Out:
# Classification Report
#                  precision    recall  f1-score   support
#
# Vegetable-Fruit       0.83      0.95      0.88        96
#   Noodles-Pasta       0.74      0.86      0.80       303
#            Rice       0.89      0.95      0.92       500
#            Meat       0.98      0.97      0.98       147
#         Seafood       0.75      0.91      0.82       432
#      Fried food       0.77      0.72      0.74       335
#             Egg       0.61      0.86      0.71       148
#           Bread       0.92      0.50      0.65       500
#   Dairy product       0.68      0.85      0.76       287
#         Dessert       0.83      0.96      0.89       231
#            Soup       0.84      0.59      0.69       368
#
#        accuracy                           0.80      3347
#       macro avg       0.80      0.83      0.80      3347
#    weighted avg       0.81      0.80      0.79      3347

# %%
import pandas as pd

results_dict={'Phuong phap phan lop':['SVC (OvO)', 'LinearSVC', 'SVC (OvR)', 'KNN', 'Bayes', 'K-mean', 'MobileNetV2'],
              'Accuracy':['85.65%', '84.02%', '85.65%','78.46%', '73.77%', '43.07%', '79.42%'], 'Shape':['(6262, 4096)', '(5318, 4096)', '(6262, 4096)', 'None', '(11, 4096)', '(11, 4096)', 'None'], 'Size':['25649152', '21782528', '25649152','None', '45056', 'None', 'None'],}
pd.DataFrame(results_dict)
# Out:
#   Phuong phap phan lop Accuracy         Shape      Size
# 0            SVC (OvO)   85.65%  (6262, 4096)  25649152
# 1            LinearSVC   84.02%  (5318, 4096)  21782528
# 2            SVC (OvR)   85.65%  (6262, 4096)  25649152
# 3                  KNN   78.46%          None      None
# 4                Bayes   73.77%    (11, 4096)     45056
# 5               K-mean   43.07%    (11, 4096)      None
# 6          MobileNetV2   79.42%          None      None
